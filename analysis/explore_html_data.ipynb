# %%
import pandas as pd
import datetime
import time
import os
import requests
import codecs
import pdb
import sys
import filter_downloaded_html as fdh
import downloaded_6_20 as downloaded
import numpy as np
from bs4 import BeautifulSoup
import pprint as pp

# %% [markdown]
# Read the data

# %%
url_list = pd.read_csv('data/startup_url_list.csv')
timestamp_list = os.listdir('data/optimal-timestamps')
timestamp_list = [int(file[:-15]) for file in timestamp_list]

# %% [markdown]
# Find already finished, take them out
#
# (This is hardcoded for now to prevent any bugs)

# %%
already_finished_crude = [int(f) for f in os.listdir('data/html') if not f.startswith('.')]
url_list = url_list[(url_list.entityid.isin(timestamp_list)) & (
    url_list.entityid.isin(already_finished_crude) == True)]

# %%
url_list
# Out:
#          entityid               weburl pb_companyid   startdate      lastVC  \
# 1490        58591    www.baylogics.com          NaN  1987-06-01  2002-10-29
# 1946        60590  www.btspartners.com          NaN  1998-07-01  2004-09-01
# 1961        60654      www.bullant.com          NaN  1995-01-01  2001-03-28
# 1963        60659    www.bulldogit.com          NaN  2000-12-01  2004-11-30
# 1965        60662     www.bullhorn.com          NaN  1999-08-04  2012-06-14
# ...           ...                  ...          ...         ...         ...
# 71088  1049403881      www.kirilys.com          NaN  2021-03-01  2023-01-25
# 71089  1049403944     www.prologue.xyz          NaN         NaN  2022-01-25
# 71101  1049406914          www.tea.xyz          NaN  2021-01-01  2022-11-08
# 71157  1049417039     www.quadrata.com          NaN  2021-01-01  2022-07-12
# 72203  1049634821      www.ideapro.com          NaN  1997-01-01  2022-04-01
#
#              ownershipstatus   exit_date
# 1490         Acquired/Merged  2002-10-29
# 1946         Out of Business         NaN
# 1961         Out of Business         NaN
# 1963   Private & Independent         NaN
# 1965         Acquired/Merged  2012-06-14
# ...                      ...         ...
# 71088  Private & Independent         NaN
# 71089  Private & Independent         NaN
# 71101  Private & Independent         NaN
# 71157  Private & Independent         NaN
# 72203  Private & Independent         NaN
#
# [864 rows x 7 columns]

# %% [markdown]
# Select a founding year. Let's see which years have a lot of companies

# %%
url_list['startyear'] = url_list.startdate.str.slice(start=0, stop=4)
url_list['startyear'].value_counts()
# Out:
# 2020    229
# 2021    169
# 2019    155
# 2018     71
# 2017     59
# 2016     30
# 2015     30
# 2014     11
# 2013      8
# 2022      7
# 2012      7
# 2011      6
# 2007      6
# 2010      6
# 1998      5
# 2003      5
# 2006      5
# 2009      4
# 2005      4
# 1999      3
# 1976      2
# 2008      2
# 1992      2
# 1995      2
# 2001      2
# 2004      2
# 2000      2
# 1987      1
# 1989      1
# 1986      1
# 2002      1
# 1981      1
# 1990      1
# 1978      1
# 1997      1
# 1996      1
# 1967      1
# 1994      1
# Name: startyear, dtype: int64

# %% [markdown]
# 2015 has a lot. We'll do that

# %%
url_list = url_list[url_list['startyear'] == '2015']

# %% [markdown]
# Now, let's create a bunch of statistics that describes this data. Some ideas:
#
# 1. How big is the website?
# 2. How much bigger/smaller is it than the original website?
# 3. The previous website?
# 4. How many `<a>` tags does the website have?
# 5. What are the words within each `<a>` tag?
# * Using BeautifulSoup, have a column containing an array of the innerText for each `<a>` tag within the website
# 6. Of the `<a>` tags, what proportion of the links are internal?
# * This will also use beautiful soup.
# 7. Does it have a `<meta>` tag with name "description"? If so, what is its "content"?
# 8. Does it have a `<meta>` tag with name "keywords"? If so, what is its "content" (in array form)?
# 9. Look for copyright information...how outdated is it?

# %% [markdown]
# Two function definitions that will be useful:

# %% [markdown]
# But first, create the empty DF

# %%
columns = ['entityid', 'domain', 'capture_yr', 'capture_m', 'time_from_start_m', 'website_size_kb', 'title', 'num_a_tags', 'a_innertext', 'meta_description', 'meta_keywords']

# %%
webpage_metadata = pd.DataFrame(columns=columns)

# %%
def get_htmls(entityid, base_path):
    global webpage_metadata
    htmls = []
    co_directory = os.path.join(base_path, entityid)
    years = [f for f in os.listdir(co_directory) if not f.startswith('.')]
    for year in years:
            yr_directory = os.path.join(co_directory, year)
            for month in os.listdir(yr_directory):
                index_path = os.path.join(yr_directory, month, "index.html")
                if os.path.isfile(index_path):
                    #Get file size (kb)
                    website_size_kb = os.stat(index_path).st_size / 1024
                    with open(index_path, 'r') as file:
                        html_content = file.read()
                        soup = BeautifulSoup(html_content, 'html.parser')
                        # Call a bunch of functions that give this more data
                        a_tags = soup.find_all('a')
                        num_a_tags = len(a_tags)
                        a_inner_texts = []
                        for a_tag in a_tags:
                            at_txt = str(a_tag.text)
                            at_txt = at_txt.replace("\n", "")
                            if at_txt != "":
                                a_inner_texts.append(at_txt)
                        page_title = soup.title.text
                        htmls.append(soup)
                        has_meta_description_tag = (soup.find('meta', attrs={'name': 'description'}) is not None)
                        has_meta_keywords_tag = (soup.find('meta', attrs={'name': 'keywords'}) is not None)
                        data_to_add = {
                            'entityid': entityid,
                            'capture_yr': year,
                            'capture_m': month,
                            'time_from_start_m': None,
                            'website_size_kb': website_size_kb,
                            'title': page_title,
                            'num_a_tags': num_a_tags,
                            'a_innertext': a_inner_texts,
                            'meta_description': int(has_meta_description_tag),
                            'meta_keywords': int(has_meta_keywords_tag)
                        }
                        print("Adding:", pp.pprint(data_to_add))
                        webpage_metadata = webpage_metadata.append(data_to_add, ignore_index=True)
    return htmls

# %% [markdown]
# Execution

# %%
base_path = "data/html"
companies = url_list.entityid.astype(str)
for company in companies:
    html_list = get_htmls(company, base_path)
    #Iterate through HTMLs...basically fill in all the columns
# Out:
# {'a_innertext': ["We're making work meaningful everywhere with our expanded "
#                  'international presence!Learn more',
#                  'Watch exclusive RfH Virtual sessions featuring Adam Grant '
#                  'and more!Watch On-demand',
#                  'Lattice in Raconteur: Beat the Great Resignation with a '
#                  'thriving cultureRead now â\x86\x92',
#                  'Lattice OverviewInvest in your people by turning people '
#                  'strategy into business strategy',
#                  'App IntegrationsSeamless integrations with your favorite '
#                  'software',
#                  'PerformanceReviews, 1:1s, Updates, Feedback, and Praise that '
#                  'make continuous performance a reality',
#                  'EngagementSurveys, Pulses, and eNPS to understand and act on '
#                  'how your employees feel about work',
#                  'GoalsOKR and goal management that drives performance',
#                  'GrowCompetencies, Growth Plans, and Career Paths for '
#                  'integrated, continuous employee development',
#                  'AnalyticsConnected, actionable people insights that lead to '
#                  'impact',
#                  'Remote people managementEquip managers to lead remote teams '
#                  'and get insights you need to improve employee moraleLearn '
#                  'moreâ\x86\x92',
#                  'Customers StoriesLearn why 3,700+ leaders use Lattice to '
#                  'build a strong culture',
#                  'Customer ExperienceFrom onboarding to adoption, our CX team '
#                  'supports your success',
#                  'Change Management HubCustomizable resources to help you '
#                  'drive adoption of Lattice',
#                  'Lattice UniversityLearn how to take advantage of everything '
#                  'Lattice has to offer',
#                  'Help CenterAdvice and answers from the Lattice Team.Visit '
#                  'help centerâ\x86\x92',
#                  'RfH MagazineExplore the community programs â\x80¨and content',
#                  'I â\x9d¤ï¸\x8f Humans NewsletterGet must-read HR stories '
#                  'directly to your inbox every week',
#                  'Slack Conversations15,000+ HR professionals ask questions '
#                  'and share advice',
#                  'ArticlesReadâ\x80\x88bestâ\x80\x88practicesâ\x80\x88onâ\x80\x88everythingâ\x80\x88â\x80¨relatedâ\x80\x88toâ\x80\x88peopleâ\x80\x88management',
#                  'InterviewsInterviewsâ\x80\x88withâ\x80\x88industryâ\x80\x88leadersâ\x80\x88onâ\x80\x88howâ\x80\x88to '
#                  'approachâ\x80\x88peopleâ\x80\x88operationsâ\x80\x88challenges',
#                  'PodcastsHear from industry leaders on the importance of '
#                  'â\x80¨building a "people-first" company',
#                  'eBooksDive deep on people '
#                  'managementâ\x80\x88bestâ\x80\x88practices',
#                  'WebinarsPresentations on all things related to people '
#                  'management',
#                  'TemplatesCurated templates for people teams, managers and '
#                  'employees',
#                  'Explore all resourcesEducational resources for people teams, '
#                  'managers and employees.Explore nowâ\x86\x92',
#                  'Pricing',
#                  'About UsOur mission is to make work meaningful',
#                  "Join UsWE'REÂ\xa0HIRINGHelp build engaged, high-performing "
#                  'teams, â\x80¨including ours',
#                  'Company BlogStay up to date on the latest from Lattice',
#                  'Remote People ManagementEquip managers to lead remote teams '
#                  'and get insights you need to improve employee morale.Learn '
#                  'moreâ\x86\x92',
#                  'Sign In',
#                  'Request a demo',
#                  'See Lattice',
#                  'PerformancePerformance management employees love.',
#                  'GoalsActivate every employee with transparent goals and '
#                  'OKRs.',
#                  'EngagementListen to the voice of your employees.',
#                  'GrowMake career advancement opportunities crystal clear.',
#                  'AnalyticsTurn people insights into action.',
#                  'Meet Lattice1:33{  "items": [    {      "url": '
#                  '"https://web.archive.org/web/20220226063953/https://www.youtube.com/watch?v=mIz8VKSZwwc",      '
#                  '"originalUrl": '
#                  '"https://web.archive.org/web/20220226063953/https://www.youtube.com/watch?v=mIz8VKSZwwc",      '
#                  '"width": 940,      "height": 528,      "thumbnailUrl": '
#                  '"https://web.archive.org/web/20220226063953/https://i.ytimg.com/vi/mIz8VKSZwwc/hqdefault.jpg",      '
#                  '"html": "<iframe class=\\"embedly-embed\\" '
#                  'src=\\"//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2FmIz8VKSZwwc%3Ffeature%3Doembed&display_name=YouTube&url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DmIz8VKSZwwc&image=https%3A%2F%2Fi.ytimg.com%2Fvi%2FmIz8VKSZwwc%2Fhqdefault.jpg&key=96f1f04c5f4143bcb0f2e68c87d65feb&type=text%2Fhtml&schema=youtube\\" '
#                  'width=\\"940\\" height=\\"528\\" scrolling=\\"no\\" '
#                  'title=\\"YouTube embed\\" frameborder=\\"0\\" '
#                  'allow=\\"autoplay; fullscreen\\" '
#                  'allowfullscreen=\\"true\\"></iframe>",      "type": '
#                  '"video"    }  ],  "group": ""}',
#                  'Explore customer stories',
#                  'Performance',
#                  'Engagement',
#                  'Goals',
#                  'Grow',
#                  'Analytics',
#                  'ReviewsRun performance reviews your way.',
#                  'PraisePublicly celebrate employee achievements.',
#                  'UpdatesUnblock direct reports and keep managers up to speed.',
#                  '1:1sMake 1:1s the most productive meetings on your calendar.',
#                  'FeedbackBuild a culture of continuous feedback.',
#                  'eNPSGet to the heart of your employee experience with one '
#                  'question.',
#                  'PulseCapture real-time feedback about your company culture.',
#                  'OnboardingAutomated onboarding surveys',
#                  'GoalsConnect individual achievements to business outcomes.',
#                  'OKRsDrive strategic impact with objectives & key results.',
#                  'AI-powered Sentiment AnalysisLearn how your employees really '
#                  'feel.',
#                  'Learn why 3,700+ leaders use Lattice',
#                  'Explore integrations',
#                  'Learn more',
#                  'Apply now',
#                  'Explore resources',
#                  'People Strategy: How to Invest in People and Make '
#                  'CultureUnlock the potential of your employees and teams with '
#                  'this definitive guide to people management.Get your copy now',
#                  'Request a demo',
#                  'About us',
#                  'Careershiring',
#                  'Pricing',
#                  'Customers',
#                  'Partners',
#                  'Blog',
#                  'Sign in',
#                  'Security',
#                  'Platform Overview',
#                  'Performance',
#                  'Engagement',
#                  'Goalsnew',
#                  'Grow',
#                  'Analytics',
#                  'Integrations',
#                  'How Lattice Compares',
#                  'Library',
#                  'Articles',
#                  'Interview',
#                  'Webinars',
#                  'eBooks',
#                  'Podcasts',
#                  'Community',
#                  'Templates',
#                  'RfHÂ\xa0Virtual 2021 ',
#                  'HelpÂ\xa0Center',
#                  'Privacy Statement',
#                  'Status',
#                  'PrivacyÂ\xa0Request',
#                  'Lattice University',
#                  '360 Spear St., Floor 4San Francisco, CA 94105',
#                  'customercare(at)lattice.com'],
#  'capture_m': '02',
#  'capture_yr': '2022',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 106,
#  'time_from_start_m': None,
#  'title': 'People Management | Performance and Engagement Software | Lattice',
#  'website_size_kb': 123.23828125}
# Adding: None
# {'a_innertext': ['US: SEP 21 Â\xa0 | Â\xa0EMEA: OCT 06Virtual ConferenceUS: '
#                  'SEP 21  Â\xa0|Â\xa0Â\xa0EMEA: OCTÂ\xa006Virtual '
#                  'conferenceRegister now â\x86\x92headline speakerJason '
#                  'Sudeikis',
#                  'Performance ManagementReviews, 1:1s, Updates, Feedback, and '
#                  'Praise that make continuous performance a reality',
#                  'EngagementSurveys, Pulses, and eNPS to understand and act on '
#                  'how your employees feel about work',
#                  'OKRs & GoalsOKR and goal management that drives performance',
#                  'AnalyticsConnected, actionable people insights that lead to '
#                  'impact',
#                  'GrowCompetencies, Growth Plans, and Career Paths for '
#                  'integrated, continuous employee development',
#                  'CompensationConnect performance and compensation to drive '
#                  'employee engagement and retention',
#                  'App integrationsSeamless integrations with your favorite '
#                  'softwareLearn more',
#                  'Agencies',
#                  'Professional services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Small businesses',
#                  'Enterprise',
#                  'Customer storiesLearn why 4,500+ leaders use Lattice to '
#                  'build a strong culture',
#                  'Customer ExperienceFrom onboarding to adoption, our CX team '
#                  'supports your success',
#                  'Change Management HubCustomizable resources to help you '
#                  'drive adoption of Lattice',
#                  'Lattice UniversityLearn how to take advantage of everything '
#                  'Lattice has to offer',
#                  'Help CenterAdvice and answers from the Lattice Team.Learn '
#                  'more',
#                  'Articles',
#                  'Interviews',
#                  'Podcasts',
#                  'eBooks',
#                  'Webinars',
#                  'Templates',
#                  'Explore all resourcesEducational resources for people teams, '
#                  'managers and employeesLearnÂ\xa0more',
#                  'RfHÂ\xa0MagazineExplore the community programs and content',
#                  'IÂ\xa0â\x99¥ï¸\x8f Humans NewsletterGet must-read HR stories '
#                  'directly to your inbox every week',
#                  'Slack Conversations17,000+ HR professionals ask questions '
#                  'and share advice',
#                  'Pricing',
#                  'About UsOur mission is to make work meaningful',
#                  'Join UsHiringHelp build engaged, high-performing teams, '
#                  'including ours',
#                  'NewsroomThe latest news, announcements, and blog posts',
#                  'PartnersBuilding a better way to develop high-performing '
#                  'teams, together',
#                  'Sign in',
#                  'Request a demo',
#                  'See Lattice',
#                  'PerformancePerformance management employees love.',
#                  'OKRsÂ\xa0&Â\xa0GoalsActivate every employee with transparent '
#                  'goals and OKRs.',
#                  'EngagementListen to the voice of your employees.',
#                  'GrowMake career advancement opportunities crystal clear.',
#                  'AnalyticsTurn people insights into action.',
#                  'CompensationCompensation reviews, simplified',
#                  'Meet Lattice1:33{  "items": [    {      "url": '
#                  '"https://web.archive.org/web/20220830051232/https://www.youtube.com/watch?v=mIz8VKSZwwc",      '
#                  '"originalUrl": '
#                  '"https://web.archive.org/web/20220830051232/https://www.youtube.com/watch?v=mIz8VKSZwwc",      '
#                  '"width": 940,      "height": 528,      "thumbnailUrl": '
#                  '"https://web.archive.org/web/20220830051232/https://i.ytimg.com/vi/mIz8VKSZwwc/hqdefault.jpg",      '
#                  '"html": "<iframe class=\\"embedly-embed\\" '
#                  'src=\\"//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2FmIz8VKSZwwc%3Ffeature%3Doembed&display_name=YouTube&url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DmIz8VKSZwwc&image=https%3A%2F%2Fi.ytimg.com%2Fvi%2FmIz8VKSZwwc%2Fhqdefault.jpg&key=96f1f04c5f4143bcb0f2e68c87d65feb&type=text%2Fhtml&schema=youtube\\" '
#                  'width=\\"940\\" height=\\"528\\" scrolling=\\"no\\" '
#                  'title=\\"YouTube embed\\" frameborder=\\"0\\" '
#                  'allow=\\"autoplay; fullscreen\\" '
#                  'allowfullscreen=\\"true\\"></iframe>",      "type": '
#                  '"video"    }  ],  "group": ""}',
#                  'Explore customer stories',
#                  'Performance',
#                  'Engagement',
#                  'OKRs & Goals',
#                  'Grow',
#                  'Analytics',
#                  'Compensation',
#                  'ReviewsRun performance reviews your way.',
#                  'PraisePublicly celebrate employee achievements.',
#                  'UpdatesUnblock direct reports and keep managers up to speed.',
#                  '1:1sMake 1:1s the most productive meetings on your calendar.',
#                  'FeedbackBuild a culture of continuous feedback.',
#                  'eNPSGet to the heart of your employee experience with one '
#                  'question.',
#                  'PulseCapture real-time feedback about your company culture.',
#                  'OnboardingAutomated onboarding surveys',
#                  'GoalsConnect individual achievements to business outcomes.',
#                  'OKRsDrive strategic impact with objectives & key results.',
#                  'Individual Development PlansEasy-to-launch plans that your '
#                  'employees will actually use',
#                  'AI-powered Sentiment AnalysisLearn how your employees really '
#                  'feel.',
#                  'Learn more about Compensation',
#                  'Learn why 4,500+ leaders use Lattice',
#                  'Explore integrations',
#                  'Learn more',
#                  'Join our communityResources for Humans is designed to help '
#                  'HR professionals connect, share advice, and ask '
#                  'questions.Apply now',
#                  'Lattice LibraryEducational resources for people teams, '
#                  'managers, and employees.Explore resources',
#                  'People Strategy: How to Invest in People and Make '
#                  'CultureUnlock the potential of your employees and teams with '
#                  'this definitive guide to people success.Get your copy now',
#                  'Request a demo',
#                  'About us',
#                  'Careershiring',
#                  'Pricing',
#                  'Customers',
#                  'Partners',
#                  'Blog',
#                  'Sign in',
#                  'Security',
#                  'Performance',
#                  'Engagement',
#                  'OKRs &Â\xa0Goals',
#                  'Grow',
#                  'Analytics',
#                  'Compensationnew',
#                  'Integrations',
#                  'How Lattice Compares',
#                  'Agencies',
#                  'Professional Services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Small Businesses',
#                  'Enterprise',
#                  'Library',
#                  'Articles',
#                  'Interview',
#                  'Webinars',
#                  'eBooks',
#                  'Podcasts',
#                  'Community',
#                  'Templates',
#                  'RfHÂ\xa0Virtual 2022 rsvp',
#                  'HelpÂ\xa0Center',
#                  'Privacy Statement',
#                  'Status',
#                  'PrivacyÂ\xa0Request',
#                  'Lattice University',
#                  '360 Spear St., Floor 4San Francisco, CA 94105',
#                  'customercare(at)lattice.com'],
#  'capture_m': '08',
#  'capture_yr': '2022',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 119,
#  'time_from_start_m': None,
#  'title': 'People Success Platform | Performance and Engagement Software | '
#           'Lattice',
#  'website_size_kb': 176.76953125}
# Adding: None
# {'a_innertext': ['Products',
#                  'Performance ManagementReviews, 1:1s, Updates, Feedback, and '
#                  'Praise that make continuous performance a reality',
#                  'OKRs and GoalsOKR and goal management that drives '
#                  'performance',
#                  'GrowCompetencies, Growth Plans, and Career Paths for '
#                  'integrated, continuous employee development',
#                  'EngagementSurveys, Pulses, and eNPS to understand and act on '
#                  'how your employees feel about work',
#                  'AnalyticsConnected, actionable people insights that lead to '
#                  'impact',
#                  'CompensationConnect performance and compensation to drive '
#                  'employee engagement and retention',
#                  'App integrationsSeamless integrations with your favorite '
#                  'softwareLearn more',
#                  'Solutions',
#                  'Agencies',
#                  'Professional services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Life Sciences',
#                  'Insurance',
#                  'Small businesses',
#                  'Enterprise',
#                  'Chief Executive Officers',
#                  'Human Resources Leaders',
#                  'Individual Contributors',
#                  'People Managers',
#                  'Customers',
#                  'Customers StoriesLearn why 5,000+ leaders use Lattice to '
#                  'build a strong culture',
#                  'Change Management HubCustomizable resources to help you '
#                  'drive adoption of Lattice',
#                  'Customer ExperienceFrom onboarding to adoption, our CX team '
#                  'supports your success',
#                  'Lattice UniversityLearn how to take advantage of everything '
#                  'Lattice has to offer',
#                  'Help CenterAdvice and answers from the Lattice Team.Learn '
#                  'more',
#                  'Resources for Humans',
#                  'Articles',
#                  'Podcasts',
#                  'Webinars',
#                  'Interviews',
#                  'eBooks',
#                  'Templates',
#                  'Explore all resourcesEducational resources for people teams, '
#                  'managers and employeesLearn more',
#                  'RfH MagazineExplore the community programs and content',
#                  'I ♥️ Humans NewsletterGet must-read HR stories directly to '
#                  'your inbox every week',
#                  'Slack Conversations17,000+ HR professionals ask questions '
#                  'and share advice',
#                  'Pricing',
#                  'About',
#                  'AboutOur mission is to make work meaningful',
#                  'NewsroomThe latest news, announcements, and blog posts',
#                  'Join usHelp build engaged, high-performing teams, including '
#                  'ours',
#                  'PartnersBuilding a better way to develop high-performing '
#                  'teams, together',
#                  'Sign in',
#                  'Request a demo',
#                  'See Lattice',
#                  ' PerformanceDrive performance when you need it most.',
#                  ' OKRs & GoalsActivate every employee with transparent goals '
#                  'and OKRs.',
#                  ' EngagementListen to the voice of your employees.',
#                  ' GrowMake career advancement opportunities crystal clear.',
#                  ' AnalyticsTurn people insights into action.',
#                  ' CompensationManage compensation with access to powerful '
#                  'benchmark data.',
#                  ' Meet Lattice1:30',
#                  'Explore customer stories',
#                  'Performance',
#                  'Engagement',
#                  'OKRs & Goals',
#                  'Grow',
#                  'Analytics',
#                  'Compensation',
#                  'ReviewsRun performance reviews your way.',
#                  'PraisePublicly celebrate employee achievements.',
#                  'UpdatesUnblock direct reports and keep managers up to speed.',
#                  '1:1sMake 1:1s the most productive meetings on your calendar.',
#                  'FeedbackBuild a culture of continuous feedback.',
#                  'eNPSGet to the heart of your employee experience with one '
#                  'question.',
#                  'PulseCapture real-time feedback about your company culture.',
#                  'OnboardingAutomated onboarding surveys',
#                  'GoalsConnect individual achievements to business outcomes.',
#                  'OKRsDrive strategic impact with objectives & key results.',
#                  'Individual Development PlansEasy-to-launch plans that your '
#                  'employees will actually use',
#                  'AI-powered Sentiment AnalysisLearn how your employees really '
#                  'feel.',
#                  'Confident DEIB decisionsBuild a happier, healthier, and more '
#                  'productive environment for all employees.',
#                  'BenchmarkingAccess to exclusive, industry-leading '
#                  'benchmarking data',
#                  'Learn why 4,500+ leaders use Lattice',
#                  'Explore our integrations',
#                  'Learn more',
#                  'Join our communityResources for Humans is designed to help '
#                  'HR professionals connect, share advice, and ask '
#                  'questions.Apply now',
#                  'Lattice LibraryEducational resources for people teams, '
#                  'managers, and employees.Explore resources',
#                  'People Strategy: How to Invest in People and Make Culture '
#                  'Competitive AdvantageUnlock the potential of your employees '
#                  'and teams with this definitive guide to peoples success.Get '
#                  'your copy now',
#                  'Request a demo',
#                  'About us',
#                  'Careers',
#                  'Pricing',
#                  'Customers',
#                  'Partners',
#                  'Blog',
#                  'Sign in',
#                  'Security',
#                  'Performance',
#                  'Engagement',
#                  'OKRs and Goals',
#                  'Grow',
#                  'Analytics',
#                  'CompensationNEW',
#                  'Integrations',
#                  'How Lattice Compares',
#                  'Agencies',
#                  'Professional Services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Life Sciences',
#                  'Insurance',
#                  'Small businesses',
#                  'Enterprise',
#                  'Chief Executive Officers',
#                  'Human Resources Leaders',
#                  'Library',
#                  'Articles',
#                  'Interview',
#                  'Webinars',
#                  'eBooks',
#                  'Podcasts',
#                  'Community',
#                  'Templates',
#                  'RfH Virtual 2022',
#                  'Help Center',
#                  'Privacy Statement',
#                  'Status',
#                  'Privacy Request',
#                  'Privacy Opt-Out',
#                  'Lattice University',
#                  '360 Spear St., Floor 4  San Francisco, CA 94105',
#                  'customercare(at)lattice.com'],
#  'capture_m': '02',
#  'capture_yr': '2023',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 134,
#  'time_from_start_m': None,
#  'title': 'People Success Platform | Performance and Engagement Software | '
#           'Lattice',
#  'website_size_kb': 198.650390625}
# Adding: None
# {'a_innertext': ['Products',
#                  'Performance ManagementReviews, 1:1s, Updates, Feedback, and '
#                  'Praise that make continuous performance a reality',
#                  'OKRs & GoalsOKR and goal management that drives performance',
#                  'GrowCompetencies, Growth Plans, and Career Paths for '
#                  'integrated, continuous employee development',
#                  'EngagementSurveys, Pulses, and eNPS to understand and act on '
#                  'how your employees feel about work',
#                  'AnalyticsConnected, actionable people insights that lead to '
#                  'impact',
#                  'CompensationConnect performance and compensation to drive '
#                  'employee engagement and retention',
#                  'App integrationsSeamless integrations with your favorite '
#                  'softwareLearn more',
#                  'Solutions',
#                  'Agencies',
#                  'Professional services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Life Sciences',
#                  'Insurance',
#                  'Small businesses',
#                  'Enterprise',
#                  'Chief Executive Officers',
#                  'Human Resources Leaders',
#                  'Individual Contributors',
#                  'People Managers',
#                  'Customers',
#                  'Customers StoriesLearn why 5,000+ leaders use Lattice to '
#                  'build a strong culture',
#                  'Change Management HubCustomizable resources to help you '
#                  'drive adoption of Lattice',
#                  'People Success AwardsSpotlighting organizations that are '
#                  'leading the way in HR excellence',
#                  'Customer ExperienceFrom onboarding to adoption, our CX team '
#                  'supports your success',
#                  'Lattice UniversityLearn how to take advantage of everything '
#                  'Lattice has to offer',
#                  'Help CenterAdvice and answers from the Lattice Team.Learn '
#                  'more',
#                  'Resources for Humans',
#                  'Articles',
#                  'Podcasts',
#                  'Webinars',
#                  'Interviews',
#                  'Ebooks',
#                  'Templates',
#                  'Explore all resourcesEducational resources for people teams, '
#                  'managers and employeesLearn more',
#                  'RfH MagazineExplore the community programs and content',
#                  'I ♥️ Humans NewsletterGet must-read HR stories directly to '
#                  'your inbox every week',
#                  'Slack Conversations20,000+ HR professionals ask questions '
#                  'and share advice',
#                  'Pricing',
#                  'About',
#                  'AboutOur mission is to make work meaningful',
#                  'NewsroomThe latest news, announcements, and blog posts',
#                  'Join usHelp build engaged, high-performing teams, including '
#                  'ours',
#                  'PartnersBuilding a better way to develop high-performing '
#                  'teams, together',
#                  'Sign in',
#                  'Request a demo',
#                  'See Lattice',
#                  ' PerformanceDrive performance when you need it most.',
#                  ' OKRs & GoalsActivate every employee with transparent goals '
#                  'and OKRs.',
#                  ' EngagementListen to the voice of your employees.',
#                  ' GrowMake career advancement opportunities crystal clear.',
#                  ' AnalyticsTurn people insights into action.',
#                  ' CompensationManage compensation with access to powerful '
#                  'benchmark data.',
#                  ' Meet Lattice1:30',
#                  'Explore customer stories',
#                  'Performance',
#                  ' Engagement',
#                  'OKRs & Goals',
#                  'Grow',
#                  'Analytics',
#                  'Compensation',
#                  'ReviewsRun performance reviews your way.',
#                  'PraisePublicly celebrate employee achievements.',
#                  'UpdatesUnblock direct reports and keep managers up to speed.',
#                  '1:1sMake 1:1s the most productive meetings on your calendar.',
#                  'FeedbackBuild a culture of continuous feedback.',
#                  'eNPSGet to the heart of your employee experience with one '
#                  'question.',
#                  'PulseCapture real-time feedback about your company culture.',
#                  'OnboardingAutomated onboarding surveys',
#                  'GoalsConnect individual achievements to business outcomes.',
#                  'OKRsDrive strategic impact with objectives & key results.',
#                  'Individual Development PlansEasy-to-launch plans that your '
#                  'employees will actually use',
#                  'AI-powered Sentiment AnalysisLearn how your employees really '
#                  'feel.',
#                  'Confident DEIB decisionsBuild a happier, healthier, and more '
#                  'productive environment for all employees.',
#                  'BenchmarkingAccess to exclusive, industry-leading '
#                  'benchmarking data',
#                  'Learn why 5,000+ leaders use Lattice',
#                  'Explore our integrations',
#                  'Learn more',
#                  'Join our communityResources for Humans is designed to help '
#                  'HR professionals connect, share advice, and ask '
#                  'questions.Apply now',
#                  'Lattice LibraryEducational resources for people teams, '
#                  'managers, and employees.Explore resources',
#                  'People Strategy: How to Invest in People and Make Culture '
#                  'Competitive AdvantageUnlock the potential of your employees '
#                  'and teams with this definitive guide to peoples success.Get '
#                  'your copy now',
#                  'Request a demo',
#                  'About us',
#                  'Careers',
#                  'Pricing',
#                  'Customers',
#                  'Partners',
#                  'Blog',
#                  'Sign in',
#                  'Security',
#                  'People Strategy Group',
#                  'People Success Awards',
#                  'Performance',
#                  'Engagement',
#                  'OKRs & Goals',
#                  'Grow',
#                  'Analytics',
#                  'CompensationNEW',
#                  'Integrations',
#                  'How Lattice Compares',
#                  'Agencies',
#                  'Professional Services',
#                  'Technology',
#                  'Banks and Credit Unions',
#                  'Fintech',
#                  'Life Sciences',
#                  'Insurance',
#                  'Small businesses',
#                  'Enterprise',
#                  'Chief Executive Officers',
#                  'Human Resources Leaders',
#                  'Library',
#                  'Articles',
#                  'Interview',
#                  'Webinars',
#                  'Ebooks',
#                  'Podcasts',
#                  'Community',
#                  'Templates',
#                  'RfH Virtual 2022',
#                  'Help Center',
#                  'Privacy Statement',
#                  'Status',
#                  'Privacy Request',
#                  'Privacy Opt-Out',
#                  'Lattice University',
#                  '360 Spear St., Floor 4  San Francisco, CA 94105',
#                  'customercare(at)lattice.com'],
#  'capture_m': '06',
#  'capture_yr': '2023',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 137,
#  'time_from_start_m': None,
#  'title': 'People Success Platform | Performance and Engagement Software | '
#           'Lattice',
#  'website_size_kb': 201.63671875}
# Adding: None
# {'a_innertext': ['Lattice',
#                  'Products',
#                  'ReviewsRun performance review cycles with ease.',
#                  'FeedbackGive employees feedback when it counts.',
#                  'GoalsSet performance expectations.',
#                  'Check-insStructure one-on-ones with a weekly Q&A.',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'Resources for HumansInterviews with people operations '
#                  'experts',
#                  'Help CenterLearn how to use Lattice products',
#                  'Customers',
#                  'Blog',
#                  'Sign in',
#                  'Request Demo',
#                  'Lattice',
#                  'Request Demo',
#                  'Products',
#                  'ReviewsRun performance review cycles with ease.',
#                  'FeedbackGive employees feedback when it counts.',
#                  'GoalsSet performance expectations.',
#                  'Check-insStructure one-on-ones with a weekly Q&A.',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'Resources for HumansInterviews with people operations '
#                  'experts',
#                  'Help CenterLearn how to use Lattice products',
#                  'Blog',
#                  'Customers',
#                  'Sign In',
#                  'About Us',
#                  'Pricing',
#                  'Careers',
#                  'Terms & Privacy',
#                  'Start Free Trial',
#                  'Get Demo',
#                  'ReviewsRun performance review cycles with ease.Learn more',
#                  'FeedbackFeedbackGive employees feedback when it countsLearn '
#                  'more',
#                  'GoalsSet performance expectations.Learn more',
#                  'Check-insStructure one-on-ones with a weekly Q&A.Learn more',
#                  'Learn more',
#                  'Learn more',
#                  'Learn more',
#                  'Learn more',
#                  'Request Demo',
#                  'Evolve Your Company’s Performance Management With Real-time '
#                  'Feedback',
#                  'HR’s Guide to Performance Review Questions',
#                  'How to think about the cost of employee turnover',
#                  'Explore the Library',
#                  'About us',
#                  'Customers',
#                  'Request Demo',
#                  'Sign In',
#                  'Careers',
#                  'Pricing',
#                  'Reviews',
#                  'Feedback',
#                  'Goals',
#                  'Check-ins',
#                  'Library',
#                  'Resources for Humans',
#                  'Blog',
#                  'Help Center',
#                  'Terms & Privacy',
#                  '580 Howard Street #102San Francisco, CA 94105',
#                  '[email\xa0protected]'],
#  'capture_m': '08',
#  'capture_yr': '2017',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 1,
#  'num_a_tags': 70,
#  'time_from_start_m': None,
#  'title': 'Lattice | Performance Management Software',
#  'website_size_kb': 44.7802734375}
# Adding: None
# {'a_innertext': ['Request a demo',
#                  'PerformanceContinuous performance management suite',
#                  'ReviewsRun a feedback cycle',
#                  'FeedbackGive helpful feedback',
#                  'GoalsSet expectations & drive performance',
#                  'PraiseCelebrate wins in public',
#                  '1:1sStructure meetings',
#                  'UpdatesAnswer status questions',
#                  'EngagementSurveys combined with performance attributes',
#                  'Discover the power of Lattice Analytics',
#                  'People Management LibraryActionable advice for HR, managers, '
#                  'employees & execs',
#                  'ArticlesExplore articles',
#                  'BooksExplore books',
#                  'InterviewsExplore interviews',
#                  'WebinarsExplore webinars',
#                  'Resources for HumansSlack Community of People Operations '
#                  'leaders',
#                  'Sign In',
#                  'Customers',
#                  'Pricing',
#                  'About Us',
#                  'Careers',
#                  'Terms & Privacy',
#                  'Sign in',
#                  'Request Demo',
#                  'See Lattice',
#                  'Read the case studiesâ\x86\x92',
#                  '2 min{  "items": [    {      "type": "video",      '
#                  '"originalUrl": '
#                  '"https://web.archive.org/web/20190828022357/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"url": '
#                  '"https://web.archive.org/web/20190828022357/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"html": "<iframe class=\\"embedly-embed\\" '
#                  'src=\\"//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2F4WDrCDW8MI8%3Fautoplay%3D1%26feature%3Doembed&url=http%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D4WDrCDW8MI8&image=https%3A%2F%2Fi.ytimg.com%2Fvi%2F4WDrCDW8MI8%2Fhqdefault.jpg&key=96f1f04c5f4143bcb0f2e68c87d65feb&autoplay=1&type=text%2Fhtml&schema=youtube\\" '
#                  'width=\\"940\\" height=\\"528\\" scrolling=\\"no\\" '
#                  'frameborder=\\"0\\" allow=\\"autoplay; fullscreen\\" '
#                  'allowfullscreen=\\"true\\"></iframe>",      "thumbnailUrl": '
#                  '"https://web.archive.org/web/20190828022357/https://i.ytimg.com/vi/4WDrCDW8MI8/hqdefault.jpg",      '
#                  '"width": 940,      "height": 528    }  ]}',
#                  'ReviewsReflect on individual performance and get formal '
#                  'feedback from peers and managers.Exploreâ\x86\x92',
#                  'FeedbackShare constructive criticism to help each other '
#                  'improve.Exploreâ\x86\x92',
#                  '1:1sCollaborate on an agenda to structure the conversation '
#                  'and collect next steps.Exploreâ\x86\x92',
#                  'GoalsEmployees know how they can impact the company and '
#                  'their career.Exploreâ\x86\x92',
#                  'PraiseCelebrate wins together and get recognized for hard '
#                  'work.Exploreâ\x86\x92',
#                  'UpdatesShare status updates with the company and '
#                  'managers.Exploreâ\x86\x92',
#                  'Learn moreâ\x86\x92',
#                  'Explore integrationsâ\x86\x92',
#                  'Customer experience teamThe Lattice team has helped hundreds '
#                  'of companies implement a continuous performance management '
#                  'process. Custom implementation plansPerformance review '
#                  'consultationsAdmin and employee trainingsBusiness '
#                  'reviewsChat and email supportTalk to product '
#                  'specialistâ\x86\x92',
#                  'Interviews with People Operations expertsVideo and podcast '
#                  'series featuring todayâ\x80\x99s leading people operations '
#                  'experts, including:Claire Hughes JohnsonCOO, StripeAnna '
#                  'BinderHead of People Ops, AsanaKim ScottAuthor of Radical '
#                  'CandorWatch the interviewsâ\x86\x92',
#                  'Peer advice from the People Ops CommunityA Slack community '
#                  'of forward-thinking Â\xa0People Operations leaders.Ask '
#                  'questions in channels ranging from diversity & inclusion to '
#                  'benefitsTalk with HR leaders from type of companies big and '
#                  'smallConnect with members from around the globe and a '
#                  'variety of industriesStay up to date on the latest trends in '
#                  'People OperationsJoin the free communityâ\x86\x92',
#                  'Performance ManagementExplore resourcesâ\x86\x92',
#                  'Managing PeopleExplore resourcesâ\x86\x92',
#                  'Performance ReviewsExplore resourcesâ\x86\x92',
#                  'Employee FeedbackExplore resourcesâ\x86\x92',
#                  'Request a demo',
#                  'About Us',
#                  "Careers We're Hiring",
#                  'Customers',
#                  'Blog',
#                  'Demo',
#                  'Sign In',
#                  'Pricing',
#                  'Integrations',
#                  'Security',
#                  'Help us Grow',
#                  'Partners',
#                  'Slack New',
#                  'Goals New',
#                  'Analytics',
#                  'Surveys',
#                  'Reviews',
#                  'Feedback',
#                  'Praise',
#                  'Performance',
#                  'One on ones',
#                  'Updates',
#                  'Mobile',
#                  'HR',
#                  'Managers',
#                  'Employee',
#                  'Library',
#                  'Articles',
#                  'Interviews',
#                  'Webinars',
#                  'Books',
#                  'Help Center',
#                  'Privacy Statement',
#                  'Status',
#                  '22 Battery St., 11th FlSan Francisco, CA 94111',
#                  'customercare@lattice.com'],
#  'capture_m': '08',
#  'capture_yr': '2019',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 88,
#  'time_from_start_m': None,
#  'title': 'People Management | Performance and Engagement Software | Lattice',
#  'website_size_kb': 56.3779296875}
# Adding: None
# {'a_innertext': ['Request a demo',
#                  'PerformanceContinuous performance management suite',
#                  'ReviewsRun a feedback cycle',
#                  'FeedbackGive helpful feedback',
#                  'GoalsSet expectations',
#                  'PraiseCelebrate wins in public',
#                  '1:1sStructure meetings',
#                  'UpdatesAnswer status questions',
#                  'EngagementSurveys combined with performance attributes',
#                  'People Management LibraryActionable advice for HR, managers, '
#                  'employees & execs',
#                  'ArticlesExplore articles',
#                  'BooksExplore books',
#                  'InterviewsExplore interviews',
#                  'WebinarsExplore webinars',
#                  'Resources for HumansSlack Community of People Operations '
#                  'leaders',
#                  'Sign In',
#                  'Customers',
#                  'Pricing',
#                  'About Us',
#                  'Pricing',
#                  'Careers',
#                  'Terms & Privacy',
#                  'Sign in',
#                  'Request Demo',
#                  'See Lattice',
#                  'Read their storiesâ\x86\x92',
#                  'Stephanie MardellVP of People, ButtonPeople truly enjoy '
#                  'using this tool. They enjoy the user interface, the '
#                  'simplicity. Everyone at Button loves the Lattice '
#                  'platform.â\x80\x9dNamed one of the Best Places to Work by:',
#                  'Heather DoshayVP of PeopleWe ultimately went with Lattice '
#                  'because it was simple and easy to use for admins and '
#                  'usersâ\x80\x9dNamed one of the Best Places to Work by:',
#                  'Lynley FlanaganSr. People Ops ManagerLattice has completely '
#                  'automated and streamlined our process, reducing the time '
#                  'spent per-review by hours. We care about creating a strong '
#                  'feedback culture at Glossier and Lattice has made that a '
#                  'reality.â\x80\x9dWe care about creating a strong feedback '
#                  'culture at Glossier and Lattice has made that a '
#                  'reality.Named one of the Best Places to Work by:',
#                  '2 min{  "items": [    {      "type": "video",      '
#                  '"originalUrl": '
#                  '"https://web.archive.org/web/20190128022221/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"url": '
#                  '"https://web.archive.org/web/20190128022221/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"html": "<iframe class=\\"embedly-embed\\" '
#                  'src=\\"//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2F4WDrCDW8MI8%3Fautoplay%3D1%26feature%3Doembed&url=http%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D4WDrCDW8MI8&image=https%3A%2F%2Fi.ytimg.com%2Fvi%2F4WDrCDW8MI8%2Fhqdefault.jpg&key=96f1f04c5f4143bcb0f2e68c87d65feb&autoplay=1&type=text%2Fhtml&schema=youtube\\" '
#                  'width=\\"940\\" height=\\"528\\" scrolling=\\"no\\" '
#                  'frameborder=\\"0\\" allow=\\"autoplay; fullscreen\\" '
#                  'allowfullscreen=\\"true\\"></iframe>",      "thumbnailUrl": '
#                  '"https://web.archive.org/web/20190128022221/https://i.ytimg.com/vi/4WDrCDW8MI8/hqdefault.jpg",      '
#                  '"width": 940,      "height": 528    }  ]}',
#                  'ReviewsReflect on individual performance and get formal '
#                  'feedback from peers and managers.Exploreâ\x86\x92',
#                  'FeedbackShare constructive criticism to help each other '
#                  'improve.Exploreâ\x86\x92',
#                  '1:1sCollaborate on an agenda to structure the conversation '
#                  'and collect next steps.Exploreâ\x86\x92',
#                  'GoalsUnderstand how to make an impact on the company and '
#                  'career.Exploreâ\x86\x92',
#                  'PraiseCelebrate wins together and get recognized for hard '
#                  'work.Exploreâ\x86\x92',
#                  'UpdatesShare status updates with the company and '
#                  'managers.Exploreâ\x86\x92',
#                  'Learn moreâ\x86\x92',
#                  'Explore integrationsâ\x86\x92',
#                  'Customer experience teamThe Lattice team has helped hundreds '
#                  'of companies implement a continuous performance management '
#                  'process. Custom implementation plansPerformance review '
#                  'consultationsAdmin and employee trainingsBusiness '
#                  'reviewsChat and email supportTalk to product '
#                  'specialistâ\x86\x92',
#                  'Interviews with People Operations expertsVideo and podcast '
#                  'series featuring todayâ\x80\x99s leading people operations '
#                  'experts, including:Claire Hughes JohnsonCOO, StripeAnna '
#                  'BinderHead of People Ops, AsanaKim ScottAuthor of Radical '
#                  'CandorWatch the interviewsâ\x86\x92',
#                  'Peer advice from the People Ops CommunityA Slack community '
#                  'of forward-thinking Â\xa0People Operations leaders.Ask '
#                  'questions in channels ranging from diversity & inclusion to '
#                  'benefitsTalk with HR leaders from type of companies big and '
#                  'smallConnect with members from around the globe and a '
#                  'variety of industriesStay up to date on the latest trends in '
#                  'People OperationsJoin the free communityâ\x86\x92',
#                  'Performance ManagementExplore resourcesâ\x86\x92',
#                  'Managing PeopleExplore resourcesâ\x86\x92',
#                  'Performance ReviewsExplore resourcesâ\x86\x92',
#                  'Employee FeedbackExplore resourcesâ\x86\x92',
#                  'Request a demo',
# ...
#                  'build a strong cultureRead customer stories',
#                  'Customer ExperienceFrom onboarding to adoption, our CX team '
#                  'supports your success.Meet Your Team',
#                  'Change Management HubCustomizable resources to help you '
#                  'drive adoption of Lattice.Access Resources',
#                  'Lattice UniversityLearn how to take advantage of everything '
#                  'Lattice has to offer.Enroll now',
#                  'Help CenterAdvice and answers from the Lattice Team.Visit '
#                  'help center',
#                  'Lattice libraryEducational resources for people teams, '
#                  'managers and employeesExplore resources',
#                  'HR and People Teams',
#                  'Managers',
#                  'Employees',
#                  '.',
#                  'Articles',
#                  'eBooks',
#                  'Interviews',
#                  'Webinars',
#                  'Podcast',
#                  'Employee Feedback',
#                  'Employee Engagement',
#                  'Performance Management',
#                  'Performance Reviews',
#                  'Managing People',
#                  'Goals and OKRs',
#                  'Community HubCommunity programs and contentJoin the '
#                  'community',
#                  'I â\x9d¤ï¸\x8f Humans NewsletterSeries with exclusive '
#                  'accessSign up',
#                  'Slack Conversations9,000+ HR professionals ask questions and '
#                  'share adviceJoin the conversation',
#                  'LATTICE EVENTSExpand your network and gain new skillsSee '
#                  "what's happening",
#                  'Resources for humans virtual Sept. 16, 2020People Strategy '
#                  'in the New World of WorkRegister â\x80\x94 100% Free',
#                  'About usWe make peoplemanagement softwareLearn more',
#                  'join us WEâ\x80\x99RE HIRINGHelp build engaged, '
#                  'high-performing teamsCareers at Lattice',
#                  'BlogCompany updates from the team Read our blog',
#                  'Pricing',
#                  'Security',
#                  'Refer a friend',
#                  'Sign In',
#                  'Request a demo',
#                  'See Lattice',
#                  'Read the case studiesâ\x86\x92',
#                  '2 min{  "items": [    {      "type": "video",      '
#                  '"originalUrl": '
#                  '"https://web.archive.org/web/20200818054702/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"url": '
#                  '"https://web.archive.org/web/20200818054702/https://www.youtube.com/watch?v=4WDrCDW8MI8?autoplay=1",      '
#                  '"html": "<iframe class=\\"embedly-embed\\" '
#                  'src=\\"//cdn.embedly.com/widgets/media.html?src=https%3A%2F%2Fwww.youtube.com%2Fembed%2F4WDrCDW8MI8%3Fautoplay%3D1%26feature%3Doembed&url=http%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D4WDrCDW8MI8&image=https%3A%2F%2Fi.ytimg.com%2Fvi%2F4WDrCDW8MI8%2Fhqdefault.jpg&key=96f1f04c5f4143bcb0f2e68c87d65feb&autoplay=1&type=text%2Fhtml&schema=youtube\\" '
#                  'width=\\"940\\" height=\\"528\\" scrolling=\\"no\\" '
#                  'frameborder=\\"0\\" allow=\\"autoplay; fullscreen\\" '
#                  'allowfullscreen=\\"true\\"></iframe>",      "thumbnailUrl": '
#                  '"https://web.archive.org/web/20200818054702/https://i.ytimg.com/vi/4WDrCDW8MI8/hqdefault.jpg",      '
#                  '"width": 940,      "height": 528    }  ]}',
#                  'ReviewsReflect on individual performance and get formal '
#                  'feedback from peers and managers.Exploreâ\x86\x92',
#                  'FeedbackShare constructive criticism to help each other '
#                  'improve.Exploreâ\x86\x92',
#                  '1:1sCollaborate on an agenda to structure the conversation '
#                  'and collect next steps.Exploreâ\x86\x92',
#                  'GoalsEmployees know how they can impact the company and '
#                  'their career.Exploreâ\x86\x92',
#                  'PraiseCelebrate wins together and get recognized for hard '
#                  'work.Exploreâ\x86\x92',
#                  'UpdatesShare status updates with the company and '
#                  'managers.Exploreâ\x86\x92',
#                  'Learn moreâ\x86\x92',
#                  'Chipper N.501â\x80\x931000 employees',
#                  'Emily I.51â\x80\x93200 employees',
#                  'David C.201â\x80\x93500 employees',
#                  'Explore integrationsâ\x86\x92',
#                  'Customer experience teamThe Lattice team has helped hundreds '
#                  'of companies implement a continuous performance management '
#                  'process. Custom implementation plansPerformance review '
#                  'consultationsAdmin and employee trainingsBusiness '
#                  'reviewsChat and email supportTalk to product '
#                  'specialistâ\x86\x92',
#                  'Interviews with People Operations expertsVideo and podcast '
#                  'series featuring todayâ\x80\x99s leading people operations '
#                  'experts, including:Claire Hughes JohnsonCOO, StripeAnna '
#                  'BinderHead of People Ops, AsanaKim ScottAuthor of Radical '
#                  'CandorWatch the interviewsâ\x86\x92',
#                  'Peer advice from the People Ops CommunityA Slack community '
#                  'of forward-thinking Â\xa0People Operations leaders.Ask '
#                  'questions in channels ranging from diversity & inclusion to '
#                  'benefitsTalk with HR leaders from type of companies big and '
#                  'smallConnect with members from around the globe and a '
#                  'variety of industriesStay up to date on the latest trends in '
#                  'People OperationsJoin the free communityâ\x86\x92',
#                  'Performance ManagementExplore resourcesâ\x86\x92',
#                  'Managing PeopleExplore resourcesâ\x86\x92',
#                  'Performance ReviewsExplore resourcesâ\x86\x92',
#                  'Employee FeedbackExplore resourcesâ\x86\x92',
#                  'See Lattice in Action',
#                  'About Us',
#                  "Careers We're Hiring",
#                  'Customers',
#                  'Blog',
#                  'Demo',
#                  'Sign In',
#                  'Pricing',
#                  'Integrations',
#                  'Security',
#                  'Help us Grow',
#                  'Partners',
#                  'eNPS New',
#                  'Pulse New',
#                  'Slack ',
#                  'Goals',
#                  'Analytics',
#                  'Surveys',
#                  'Reviews',
#                  'Feedback',
#                  'Praise',
#                  'Performance',
#                  'One on ones',
#                  'Updates',
#                  'Mobile',
#                  'HR',
#                  'Managers',
#                  'Employee',
#                  'Library',
#                  'Articles',
#                  'Interviews',
#                  'Webinars',
#                  'Books',
#                  'Help Center',
#                  'Privacy Statement',
#                  'Status',
#                  'Privacy Request',
#                  '600 Battery St., Floor 2San Francisco, CA 94111',
#                  'customercare@lattice.com'],
#  'capture_m': '08',
#  'capture_yr': '2020',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 0,
#  'num_a_tags': 121,
#  'time_from_start_m': None,
#  'title': 'People Management | Performance and Engagement Software | Lattice',
#  'website_size_kb': 67.5107421875}
# Adding: None
# {'a_innertext': ['Lattice',
#                  'Products',
#                  'ReviewsRun performance review cycles with ease.',
#                  'FeedbackGive employees feedback when it counts.',
#                  'GoalsSet performance expectations.',
#                  'Check-insStructure one-on-ones with a weekly Q&A.',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'Resources for HumansInterviews with people operations '
#                  'experts',
#                  'Help CenterLearn how to use Lattice products',
#                  'Customers',
#                  'Blog',
#                  'Sign in',
#                  'Request a demo',
#                  'Request a demo',
#                  'Lattice',
#                  'Request Demo',
#                  'Products',
#                  'ReviewsRun performance review cycles with ease.',
#                  'FeedbackGive employees feedback when it counts.',
#                  'GoalsSet performance expectations.',
#                  'Check-insStructure one-on-ones with a weekly Q&A.',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'Resources for HumansInterviews with people operations '
#                  'experts',
#                  'Help CenterLearn how to use Lattice products',
#                  'Blog',
#                  'Customers',
#                  'Sign In',
#                  'About Us',
#                  'Pricing',
#                  'Careers',
#                  'Terms & Privacy',
#                  'GoalsEmployees set performance and development goals.',
#                  'FeedbackEmployees share feedback in the moment.',
#                  'Check-insEmployees meet with managers to get feedback every '
#                  'week.',
#                  'ReviewsEmployees take a step back and reflect on individual, '
#                  'manager, and team performance.',
#                  'Request a demo',
#                  'About us',
#                  'Customers',
#                  'Request Demo',
#                  'Sign In',
#                  'Careers',
#                  'Pricing',
#                  'Reviews',
#                  'Feedback',
#                  'Goals',
#                  'Check-ins',
#                  'Library',
#                  'Resources for Humans',
#                  'Blog',
#                  'Integrations',
#                  'Help Center',
#                  'Terms & Privacy',
#                  '22 Battery St. - 11th FloorSan Francisco, CA 94111',
#                  '[email\xa0protected]'],
#  'capture_m': '02',
#  'capture_yr': '2018',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 1,
#  'num_a_tags': 62,
#  'time_from_start_m': None,
#  'title': 'Performance Management & Employee Development Software',
#  'website_size_kb': 59.35546875}
# Adding: None
# {'a_innertext': ['Lattice',
#                  'Products',
#                  'PerformanceContinuous performance management solution',
#                  'ReviewsRun a feedback cycle',
#                  'GoalsSet expectations',
#                  'FeedbackGive helpful feedback',
#                  'PraiseCelebrate wins in public',
#                  '1:1sStructure meetings',
#                  'UpdatesAnswer status questions',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'InterviewsConversations with people operations experts',
#                  'CommunityJoin our Slack community to learn with industry '
#                  'peers',
#                  'Help CenterLearn how to use Lattice products',
#                  'Customers',
#                  'Blog',
#                  'Sign in',
#                  'Request a demo',
#                  'Request a demo',
#                  'Lattice',
#                  'Request Demo',
#                  'Products',
#                  'PerformanceContinuous performance management solution',
#                  'ReviewsRun a feedback cycle',
#                  'GoalsSet expectations',
#                  'FeedbackGive helpful feedback',
#                  'PraiseCelebrate wins in public',
#                  '1:1sStructure meetings',
#                  'UpdatesAnswer status questions',
#                  'Resources',
#                  'LibraryBooks and videos on performance management',
#                  'Resources for HumansInterviews with people operations '
#                  'experts',
#                  'CommunityJoin our Slack community to learn with industry '
#                  'peers',
#                  'Help CenterLearn how to use Lattice products',
#                  'Blog',
#                  'Customers',
#                  'Sign In',
#                  'About Us',
#                  'Pricing',
#                  'Careers',
#                  'Terms & Privacy',
#                  'See Lattice',
#                  'How Birchbox Refreshed Its Performance Management '
#                  'ProcessRead the case study',
#                  'ReviewsReflect on individual performance and get formal '
#                  'feedback from peers and managers.Learn more',
#                  'FeedbackShare constructive criticism to help each other '
#                  'improve.Learn more',
#                  'PraiseCelebrate wins together and get recognized for hard '
#                  'work.Learn more',
#                  'GoalsUnderstand how to make an impact on the company and '
#                  'career.Learn more',
#                  '1:1sCollaborate on an agenda to structure the conversation '
#                  'and collect next steps.Learn more',
#                  'UpdatesShare status updates with the company and '
#                  'managers.Learn more',
#                  'HRDesign the solution that’s right\xa0for your cultureLearn '
#                  'more',
#                  'ManagersTools for people\xa0managersLearn more',
#                  'EmployeeSimple, yet engaging\xa0for employeesLearn more',
#                  '15:57Kim Scott: How to Give Candid Feedback',
#                  "19:12Anna Binder: How Asana Built Silicon Valley's Leading "
#                  'Company Culture',
#                  '28:24Katelin Holloway: How Reddit Approaches People Ops',
#                  '43:36Josh Bersin: How HR has evolved over the past 10 years '
#                  'and what happens next',
#                  "29:54Claire Hughes Johnson: How Stripe's COO approaches "
#                  'company building',
#                  '30:12Sarah Nahm: How to Hire Top Talent',
#                  'Request a demo',
#                  'About us',
#                  'Customers',
#                  'Request Demo',
#                  'Sign In',
#                  'Careers',
#                  'Pricing',
#                  'Reviews',
#                  'Feedback',
#                  'Goals',
#                  'Praise',
#                  'One on ones',
#                  'Updates',
#                  'HR',
#                  'Managers',
#                  'Employee',
#                  'Library',
#                  'Resources for Humans',
#                  'Blog',
#                  'Integrations',
#                  'Help Center',
#                  'Terms',
#                  'Privacy Statement',
#                  '22 Battery St. - 11th FloorSan Francisco, CA 94111',
#                  '[email\xa0protected]'],
#  'capture_m': '08',
#  'capture_yr': '2018',
#  'entityid': '674030',
#  'meta_description': 1,
#  'meta_keywords': 1,
#  'num_a_tags': 89,
#  'time_from_start_m': None,
#  'title': 'People Management Platform: Performance, Development, & Engagement '
#           'Software for Employees',
#  'website_size_kb': 61.7958984375}
# Adding: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 4
#       2 companies = url_list.entityid.astype(str)
#       3 for company in companies:
# ----> 4     html_list = get_htmls(company, base_path)
#       5     #Iterate through HTMLs...basically fill in all the columns
#
# Cell In[47], line 25, in get_htmls(entityid, base_path)
#      23     if at_txt != "":
#      24         a_inner_texts.append(at_txt)
# ---> 25 page_title = soup.title.text
#      26 htmls.append(soup)
#      27 has_meta_description_tag = (soup.find('meta', attrs={'name': 'description'}) is not None)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
companies
# Out:
# 28081        674030
# 29645        683889
# 47102    1016894171
# 47716    1017906536
# 52729    1026782984
# 52894    1026822557
# 53099    1026877610
# 53428    1027782074
# 59321    1043793110
# 59539    1043829200
# 59751    1043860124
# 59762    1043861753
# 60938    1044326531
# 61120    1044869132
# 61144    1045002818
# 61505    1045432973
# 61514    1045435169
# 61843    1045507583
# 62274    1045851707
# 62357    1045865054
# 63321    1046221364
# 63745    1046313749
# 64078    1046400122
# 65205    1046714078
# 66141    1047046979
# 66177    1047055511
# 66379    1047101330
# 68604    1048396475
# 69320    1048935305
# 70320    1049178170
# Name: entityid, dtype: object

# %%
webpage_metadata
# Out:
#    entityid  domain capture_yr capture_m time_from_start_m  website_size_kb  \
# 0    674030     NaN       2022        02              None       123.238281
# 1    674030     NaN       2022        08              None       176.769531
# 2    674030     NaN       2023        02              None       198.650391
# 3    674030     NaN       2023        06              None       201.636719
# 4    674030     NaN       2017        08              None        44.780273
# 5    674030     NaN       2019        08              None        56.377930
# 6    674030     NaN       2019        01              None        53.999023
# 7    674030     NaN       2021        08              None        91.258789
# 8    674030     NaN       2021        01              None        80.781250
# 9    674030     NaN       2020        02              None        61.589844
# 10   674030     NaN       2020        08              None        67.510742
# 11   674030     NaN       2018        02              None        59.355469
# 12   674030     NaN       2018        08              None        61.795898
#
#                                                 title num_a_tags  \
# 0   People Management | Performance and Engagement...        106
# 1   People Success Platform | Performance and Enga...        119
# 2   People Success Platform | Performance and Enga...        134
# 3   People Success Platform | Performance and Enga...        137
# 4           Lattice | Performance Management Software         70
# 5   People Management | Performance and Engagement...         88
# 6   People Management: Performance & Engagement So...         84
# 7   People Management | Performance and Engagement...         97
# 8   People Management | Performance and Engagement...         96
# 9   People Management | Performance and Engagement...        114
# 10  People Management | Performance and Engagement...        121
# 11  Performance Management & Employee Development ...         62
# 12  People Management Platform: Performance, Devel...         89
#
#                                           a_innertext meta_description  \
# 0   [We're making work meaningful everywhere with ...                1
# 1   [US: SEP 21 Â  | Â EMEA: OCT 06Virtual Confere...                1
# 2   [Products, Performance ManagementReviews, 1:1s...                1
# 3   [Products, Performance ManagementReviews, 1:1s...                1
# 4   [Lattice, Products, ReviewsRun performance rev...                1
# 5   [Request a demo, PerformanceContinuous perform...                1
# 6   [Request a demo, PerformanceContinuous perform...                1
# 7   [          Join us Sept. 22 to hear Serena Wil...                1
# 8   [\t\t\t\t\t Employee Development for the New W...                1
# 9   [PerformanceContinuous Performance ManagementD...                1
# 10  [PerformanceContinuous Performance ManagementD...                1
# 11  [Lattice, Products, ReviewsRun performance rev...                1
# 12  [Lattice, Products, PerformanceContinuous perf...                1
#
#    meta_keywords
# 0              0
# 1              0
# 2              0
# 3              0
# 4              1
# 5              0
# 6              0
# 7              0
# 8              0
# 9              0
# 10             0
# 11             1
# 12             1
